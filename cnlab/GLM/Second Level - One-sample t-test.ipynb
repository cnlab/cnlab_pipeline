# %% [markdown]
# ### Instructions
#
# 1. Plug in the `model_path`
# 2. From `Run` menu, select `Restart Kernel and Run All Cells`
# 3. From `View` menu, select `Collapse All Code`

# %%
model_path = '/data00/projects/megameta/scripts/jupyter_megameta/l1analysis/smoking_UCLA/task-ads_model-bin3.json'

# %%
import os, glob, re, sys, json, copy  

import nipype.interfaces.io as nio           
import nipype.interfaces.spm as spm    
import nipype.interfaces.matlab as mlab     
import nipype.pipeline.engine as pe 
import nipype.interfaces.utility as util

import pandas as pd
import numpy as np
import scipy as sp
import scipy.io as sio

from nilearn import plotting

# %%
def ensure_list(obj):
    if type(obj) is not list:
        return [obj]
    else:
        return obj

def copy_from_template(target, template):
    for key, item in template.items():
        if key not in target.keys():
            target[key] = copy.deepcopy(template[key])
        elif type(item) is dict:
            copy_from_template(target[key], template[key])

# %%
with open(model_path, 'r') as f:
    model = json.load(f)

for template_path in ensure_list(model.get("Template", [])):
    with open(template_path, 'r') as f:
        template = json.load(f)
    copy_from_template(model, template)
    
env = model['Environment']
job_name = 'task-{}_model-{}'.format(model['Info']['task'], model['Info']['model'])

# %%
mlab.MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")
mlab.MatlabCommand.set_default_paths(env["spm_path"])

# %%
con_df = []
print("Aggregating contrast files...")

for sub_folder in glob.glob(os.path.join(env['output_path'], job_name, 'sub-*')):
    
    if not os.path.isdir(sub_folder):
        continue
    
    sub = os.path.basename(sub_folder)
    
    spm_file = os.path.join(sub_folder, 'SPM.mat')
    if not os.path.exists(spm_file):
        continue
    
    spm_mat = sio.loadmat(spm_file, 
               squeeze_me=True, struct_as_record=False)
    
    for n, con in enumerate(spm_mat['SPM'].xCon, start=1):
        con_file = os.path.join(sub_folder, f"con_{n:04d}.nii")
        if os.path.exists(con_file):
            con_df.append({'sub': sub,
                          'con': con.name,
                          'path': con_file})
        
con_df = pd.DataFrame(con_df)
con_df.to_csv(os.path.join(env['output_path'], job_name, 'contrasts.csv'), index=False)
con_df.pivot_table(index='con', values='sub', aggfunc='count')
# Out:
# Aggregating contrast files...
#                                      sub
# con
# non_message_event                     32
# pure_message_0.0                      32
# pure_message_1.0                      32
# pure_message_2.0                      32
# pure_message_2.0 > pure_message_0.0   32
# pure_message_no_pmod                  32

# %%
def get_contrast_files(contrast_name, contrast_df):
    return contrast_df.query(f'con == "{contrast_name}"').path.tolist()

# %%
l2analysis_path = os.path.join(env['output_path'], job_name, "l2analysis")

# %%
l2analysis = pe.Workflow(base_dir=os.path.join(env['working_path'], job_name), name='l2analysis')

infosource = pe.Node(util.IdentityInterface(fields=['contrast_name']),
                  name="infosource")
infosource.iterables = ('contrast_name', con_df.con.unique().tolist())

getcontrastfiles = pe.Node(util.Function(input_names=['contrast_name', 'contrast_df'],
                                        output_names=['contrast_files'],
                                        function=get_contrast_files),
                    name='getcontrastfiles')
getcontrastfiles.inputs.contrast_df = con_df

# One Sample T-Test Design - creates one sample T-Test Design
onesamplettestdes = pe.Node(spm.OneSampleTTestDesign(),
                         name="onesampttestdes")

# EstimateModel - estimate the parameters of the model
level2estimate = pe.Node(spm.EstimateModel(estimation_method={'Classical': 1}),
                      name="level2estimate")

# EstimateContrast - estimates simple group contrast
level2conestimate = pe.Node(spm.EstimateContrast(group_contrast=True), 
                            name="level2conestimate")
cont = ['Group', 'T', ['mean'], [1]]
level2conestimate.inputs.contrasts = [cont]

# Datasink - creates output folder for important outputs
datasink = pe.Node(nio.DataSink(base_directory=l2analysis_path), 
                   name="datasink")
datasink.inputs.substitutions = [('_contrast_name_', '')]

# Connect workflow
l2analysis.connect([(infosource, getcontrastfiles, [('contrast_name', 'contrast_name')]),
                    (getcontrastfiles, onesamplettestdes, [('contrast_files', 'in_files')]),
                    (onesamplettestdes, level2estimate, [('spm_mat_file',
                                                          'spm_mat_file')] ),
                    (level2estimate, level2conestimate, [('spm_mat_file',
                                                          'spm_mat_file'),
                                                         ('beta_images',
                                                          'beta_images'),
                                                         ('residual_image',
                                                          'residual_image')]),
                    (level2conestimate, datasink, [('spm_mat_file',
                                                    '@spm_mat'),
                                                   ('spmT_images',
                                                    '@T'),
                                                   ('con_images',
                                                    '@con')])
                   ])

l2analysis.run()
# Out:
# 201217-11:45:49,860 nipype.workflow INFO:
# 	 Workflow l2analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 201217-11:45:50,7 nipype.workflow INFO:
# 	 Running serially.
# 201217-11:45:50,8 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0pure_message_0.0/getcontrastfiles".
# 201217-11:45:50,163 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 201217-11:45:50,279 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 201217-11:45:50,280 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0pure_message_0.0/onesampttestdes".
# 201217-11:45:50,395 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 201217-11:46:12,759 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 201217-11:46:12,760 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0pure_message_0.0/level2estimate".
# 201217-11:46:12,915 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 201217-11:46:39,7 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 201217-11:46:39,11 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0pure_message_0.0/level2conestimate".
# 201217-11:46:39,153 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 201217-11:46:57,238 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 201217-11:46:57,240 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0pure_message_0.0/datasink".
# 201217-11:46:57,378 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 201217-11:46:57,392 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0pure_message_0.0/SPM.mat -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_2.0pure_message_0.0/SPM.mat
# 201217-11:46:57,429 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0pure_message_0.0/spmT_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_2.0pure_message_0.0/spmT_0001.nii
# 201217-11:46:57,447 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0pure_message_0.0/con_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_2.0pure_message_0.0/con_0001.nii
# 201217-11:46:57,513 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 201217-11:46:57,514 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_1.0/getcontrastfiles".
# 201217-11:46:57,647 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 201217-11:46:57,835 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 201217-11:46:57,836 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_1.0/onesampttestdes".
# 201217-11:46:57,958 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 201217-11:47:20,730 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 201217-11:47:20,731 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_1.0/level2estimate".
# 201217-11:47:20,874 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 201217-11:47:49,46 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 201217-11:47:49,48 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_1.0/level2conestimate".
# 201217-11:47:49,193 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 201217-11:48:07,732 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 201217-11:48:07,735 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_1.0/datasink".
# 201217-11:48:07,853 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 201217-11:48:07,856 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_1.0/SPM.mat -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_1.0/SPM.mat
# 201217-11:48:07,893 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_1.0/spmT_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_1.0/spmT_0001.nii
# 201217-11:48:07,909 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_1.0/con_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_1.0/con_0001.nii
# 201217-11:48:07,982 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 201217-11:48:07,983 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_0.0/getcontrastfiles".
# 201217-11:48:08,140 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 201217-11:48:08,331 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 201217-11:48:08,333 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_0.0/onesampttestdes".
# 201217-11:48:08,449 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 201217-11:48:30,962 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 201217-11:48:30,965 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_0.0/level2estimate".
# 201217-11:48:31,122 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 201217-11:48:59,124 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 201217-11:48:59,126 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_0.0/level2conestimate".
# 201217-11:48:59,290 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 201217-11:49:17,453 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 201217-11:49:17,455 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_0.0/datasink".
# 201217-11:49:17,644 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 201217-11:49:17,647 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_0.0/SPM.mat -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_0.0/SPM.mat
# 201217-11:49:17,680 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_0.0/spmT_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_0.0/spmT_0001.nii
# 201217-11:49:17,694 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_0.0/con_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_0.0/con_0001.nii
# 201217-11:49:17,765 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 201217-11:49:17,767 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_no_pmod/getcontrastfiles".
# 201217-11:49:17,909 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 201217-11:49:18,99 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 201217-11:49:18,101 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_no_pmod/onesampttestdes".
# 201217-11:49:18,236 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 201217-11:49:41,944 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 201217-11:49:41,948 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_no_pmod/level2estimate".
# 201217-11:49:42,149 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 201217-11:50:12,195 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 201217-11:50:12,197 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_no_pmod/level2conestimate".
# 201217-11:50:12,384 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 201217-11:50:30,556 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 201217-11:50:30,558 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_no_pmod/datasink".
# 201217-11:50:30,716 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 201217-11:50:30,719 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_no_pmod/SPM.mat -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_no_pmod/SPM.mat
# 201217-11:50:30,760 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_no_pmod/spmT_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_no_pmod/spmT_0001.nii
# 201217-11:50:30,776 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_no_pmod/con_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_no_pmod/con_0001.nii
# 201217-11:50:30,853 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 201217-11:50:30,855 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_non_message_event/getcontrastfiles".
# 201217-11:50:31,56 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 201217-11:50:31,275 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 201217-11:50:31,276 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_non_message_event/onesampttestdes".
# 201217-11:50:31,407 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 201217-11:50:54,490 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 201217-11:50:54,493 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_non_message_event/level2estimate".
# 201217-11:50:54,641 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 201217-11:51:20,927 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 201217-11:51:20,941 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_non_message_event/level2conestimate".
# 201217-11:51:21,134 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 201217-11:51:39,396 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 201217-11:51:39,398 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_non_message_event/datasink".
# 201217-11:51:39,545 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 201217-11:51:39,547 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_non_message_event/SPM.mat -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/non_message_event/SPM.mat
# 201217-11:51:39,585 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_non_message_event/spmT_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/non_message_event/spmT_0001.nii
# 201217-11:51:39,602 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_non_message_event/con_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/non_message_event/con_0001.nii
# 201217-11:51:39,674 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 201217-11:51:39,676 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0/getcontrastfiles".
# 201217-11:51:39,827 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 201217-11:51:40,27 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 201217-11:51:40,28 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0/onesampttestdes".
# 201217-11:51:40,169 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 201217-11:52:07,465 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 201217-11:52:07,468 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0/level2estimate".
# 201217-11:52:07,612 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 201217-11:52:35,217 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 201217-11:52:35,220 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0/level2conestimate".
# 201217-11:52:35,404 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 201217-11:52:53,340 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 201217-11:52:53,343 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/megameta/smoking_UCLA/working/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0/datasink".
# 201217-11:52:53,469 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 201217-11:52:53,473 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0/SPM.mat -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_2.0/SPM.mat
# 201217-11:52:53,508 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0/spmT_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_2.0/spmT_0001.nii
# 201217-11:52:53,523 nipype.interface INFO:
# 	 sub: /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/_contrast_name_pure_message_2.0/con_0001.nii -> /data00/projects/megameta/smoking_UCLA/derivatives/nipype/task-ads_model-bin3/l2analysis/pure_message_2.0/con_0001.nii
# 201217-11:52:53,590 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".

# %%
p_val = 0.001
p001_uncorrected = sp.stats.norm.isf(p_val)

for con_folder in glob.glob(os.path.join(l2analysis_path, "*")):
    if not os.path.isdir(con_folder):
        continue
    
    con_name = os.path.basename(con_folder)
    t_map = os.path.join(con_folder, "spmT_0001.nii")
    
    if not os.path.exists(t_map):
        continue
    
    plotting.plot_stat_map(
        t_map, threshold=p001_uncorrected, colorbar=True, display_mode='z',
        title=f'{con_name} (uncorr p < 0.001)')
    
    plotting.show()
